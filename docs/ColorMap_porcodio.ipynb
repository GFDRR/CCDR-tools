# %%
From https://nbviewer.org/github/jtbaker/folium/blob/master/examples/Colormaps.ipynb

# %%
import json
import folium
import pandas as pd
import requests

us_states = "https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/us-states.json"
US_Unemployment_Oct2012 = "https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/US_Unemployment_Oct2012.csv"

geo_json_data = json.loads(requests.get(us_states).text)
unemployment = pd.read_csv(US_Unemployment_Oct2012)

unemployment_dict = unemployment.set_index("State")["Unemployment"]

# %%
import branca.colormap as cm

step = cm.StepColormap(
    ["green", "yellow", "red"], vmin=3, vmax=10, index=[3, 4, 8, 10], caption="step"
)

step
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="12" y1=
# ...

# %%
m = folium.Map([43, -100], tiles="cartodbpositron", zoom_start=4)

folium.GeoJson(
    geo_json_data,
    style_function=lambda feature: {
        "fillColor": step(unemployment_dict[feature["id"]]),
        "color": "black",
        "weight": 2,
    },
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
unemployment_dict
# Out:
# State
# AL     7.1
# AK     6.8
# AZ     8.1
# AR     7.2
# CA    10.1
# CO     7.7
# CT     8.4
# DE     7.1
# FL     8.2
# GA     8.8
# HI     5.4
# ID     6.6
# IL     8.8
# IN     8.4
# IA     5.1
# KS     5.6
# KY     8.1
# LA     5.9
# ME     7.2
# MD     6.8
# MA     6.7
# MI     9.1
# MN     5.6
# MS     9.1
# MO     6.7
# MT     5.8
# NE     3.9
# NV    10.3
# NH     5.7
# NJ     9.6
# NM     6.8
# NY     8.4
# NC     9.4
# ND     3.2
# OH     6.9
# OK     5.2
# OR     8.5
# PA     8.0
# RI    10.1
# SC     8.8
# SD     4.4
# TN     7.8
# TX     6.4
# UT     5.5
# VT     5.0
# VA     5.8
# WA     7.8
# WV     7.5
# WI     6.8
# WY     5.1
# Name: Unemployment, dtype: float64

# %%
geo_json_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 'AL',
#    'properties': {'name': 'Alabama'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.359296, 35.00118],
#       [-85.606675, 34.984749],
#       [-85.431413, 34.124869],
#       [-85.184951, 32.859696],
#       [-85.069935, 32.580372],
#       [-84.960397, 32.421541],
#       [-85.004212, 32.322956],
#       [-84.889196, 32.262709],
#       [-85.058981, 32.13674],
#       [-85.053504, 32.01077],
#       [-85.141136, 31.840985],
#       [-85.042551, 31.539753],
#       [-85.113751, 31.27686],
#       [-85.004212, 31.003013],
#       [-85.497137, 30.997536],
#       [-87.600282, 30.997536],
#       [-87.633143, 30.86609],
#       [-87.408589, 30.674397],
#       [-87.446927, 30.510088],
#       [-87.37025, 30.427934],
#       [-87.518128, 30.280057],
#       [-87.655051, 30.247195],
#       [-87.90699, 30.411504],
#       [-87.934375, 30.657966],
#       [-88.011052, 30.685351],
# ...
